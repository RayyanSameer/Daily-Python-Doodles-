# %% [markdown]
# PROBLEM 1: The Shadow
#
#     Code:
#     Python
#
#     import math
#
#     # Create a variable named math
#     math = 10
#
#     # Now try to use the module
#     print(math.pi)
#
#     Task: Run this. It will crash. Fix it so you can have the variable math_score equal to 10, but still print math.pi.

# %%
import math as mth
math =  10
math_score = 10
print(mth.pi)
print(math)
print(math_score)
# Out:
# 3.141592653589793
# 10
# 10

# %% [markdown]
# PROBLEM 2: The Specifics
#
#     Code: import datetime
#
#     Task: Change the import so I can type now() instead of datetime.datetime.now().
#
#     Constraint: You must use the from ... import ... syntax.

# %%
from datetime import now as now 
print(now())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from datetime import now as now
#       2 print(now())
#
# ImportError: cannot import name 'now' from 'datetime' (C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\datetime.py)

# %% [markdown]
# PROBLEM 3: The Alias
#
#     Task: Import the module collections but rename it to col. Create a col.Counter() object.

# %%
import collections as col

COl_Counter = col.count()
